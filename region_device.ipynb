# %%
# UK
# mobile App - can't do multiplicative due to zero and/or -ve values
# mobile web - weird trend that goes down around 2018 summer
# tablet - weird trend that goes down around 2018 summer
# unknown - can't do multiplicative due to zero and/or -ve values (additive data mostly flat with a slight increasing trend)
# desktop - weird trend that goes down around 2018 summer

# SoEu
# mobile App - can't do multiplicative due to zero and/or -ve values
# mobile web - can't do multiplicative due to zero and/or -ve values
# tablet - can't do multiplicative due to zero and/or -ve values
# unknown - can't do multiplicative due to zero and/or -ve values
# desktop - can't do multiplicative due to zero and/or -ve values

# CE
# mobile App - can't do multiplicative due to zero and/or -ve values
# unknown - can't do multiplicative due to zero and/or -ve values

# FR
# unknown - can't do multiplicative due to zero and/or -ve values

# %%
from time_series_multireg.multireg_forecast import multireg_forecast

# %%
import pandas as pd
data = pd.read_csv('/Users/akuppam/Documents/Hprog/Py/AllMetrics_Jan31/deviceNA.csv')
data.head()
# Out:
#        ds Region      Device     y
# 0  1/1/17    AMR     desktop  4925
# 1  1/1/17    AMR  mobile App   473
# 2  1/1/17    AMR  mobile web  1415
# 3  1/1/17    AMR      tablet  1338
# 4  1/1/17    AMR     Unknown   555

# %%
xAMR = multireg_forecast(data, 365, date_col="ds", measure_col="y", region_col="Region", 
                         forecasts = {"holtwinters", "arima_stlm", "sarima_stlm", "prophet"})
# Out:
# 2019-02-12 08:46:27.126 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:224 - Determining best forecast for desktop, AMR.
# 2019-02-12 08:46:27.318 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:238 - In sample actuals: 761.
# 2019-02-12 08:46:27.318 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:239 - Out sample actuals: 0.
# 2019-02-12 08:46:27.319 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:247 - Performing holtwinters on desktop, AMR.
# 2019-02-12 08:46:31.761 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:272 - holtwinters produced mape 0.066.
# 2019-02-12 08:46:31.763 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:274 - Best mape: inf.
# 2019-02-12 08:46:31.764 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:282 - New best mape: 0.066.
# ...

# %%
pred = xAMR
bestOut = pd.DataFrame(columns=pred[0])
for key in pred[0]:
    bestOut[key[0]] = list(pred[0][key][0:2]) + list(pred[0][key][2])
bestOut.to_csv('/Users/akuppam/Documents/Hprog/Py/AllMetrics_Jan31/xAMRdesktop.csv')

# %%
bestOut.head()
# Out:
#       desktop
#           AMR
# 0  arima_stlm
# 1   0.0409633
# 2     4920.07
# 3     7185.13
# 4     8457.42

# %%
xAMR = multireg_forecast(data, 365, date_col="ds", measure_col="y", region_col="Region", 
                         forecasts = {"holtwinters", "arima_stlm", "sarima_stlm", "prophet"})
# Out:
# 2019-02-12 09:41:24.888 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:224 - Determining best forecast for Unknown, AMR.
# 2019-02-12 09:41:25.127 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:238 - In sample actuals: 761.
# 2019-02-12 09:41:25.128 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:239 - Out sample actuals: 0.
# 2019-02-12 09:41:25.129 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:247 - Performing holtwinters on Unknown, AMR.
# 2019-02-12 09:41:30.869 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:272 - holtwinters produced mape 0.105.
# 2019-02-12 09:41:30.873 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:274 - Best mape: inf.
# 2019-02-12 09:41:30.874 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:282 - New best mape: 0.105.
# ...

# %%
pred = xAMR
bestOut = pd.DataFrame(columns=pred[0])
for key in pred[0]:
    bestOut[key[0]] = list(pred[0][key][0:2]) + list(pred[0][key][2])
bestOut.to_csv('/Users/akuppam/Documents/Hprog/Py/AllMetrics_Jan31/xAMR.csv')

# %%
# run soeu, ce, fr, uk

# %%
xAMR
# Out:
# ({('Unknown', 'AMR'): ('arima_stlm',
#    0.08999395066121577,
#    2017-01-01     856.429205
#    2017-01-02     940.209183
#    2017-01-03    1189.302389
#    2017-01-04    1612.356909
#    2017-01-05    1486.605497
#    2017-01-06    1142.764616
#    2017-01-07    1136.012822
#    2017-01-08    1118.382397
#    2017-01-09    1793.706916
#    2017-01-10    2926.338557
#    2017-01-11    2056.486247
#    2017-01-12    1172.475360
#    2017-01-13    1261.551152
#    2017-01-14    1161.728078
#    2017-01-15    1339.640523
#    2017-01-16    1705.537059
#    2017-01-17    1643.939925
#    2017-01-18    1316.985476
#    2017-01-19    1183.149338
#    2017-01-20    1094.455246
#    2017-01-21    1137.693840
#    2017-01-22    1361.842797
#    2017-01-23    1555.779770
#    2017-01-24    1481.335780
#    2017-01-25    1301.732690
#    2017-01-26    1195.615493
#    2017-01-27    1277.757676
#    2017-01-28    1160.283797
#    2017-01-29    1278.350271
#    2017-01-30    1404.043034
# ...

# %%
import pandas as pd
#data = pd.read_csv('/Users/akuppam/Documents/Hprog/Py/AllMetrics_Jan31/deviceUK1.csv')
#data = pd.read_csv('/Users/akuppam/Documents/Hprog/Py/AllMetrics_Jan31/deviceFR.csv')
data = pd.read_csv('/Users/akuppam/Documents/Hprog/Py/AllMetrics_Jan31/deviceCE.csv')
#data = pd.read_csv('/Users/akuppam/Documents/Hprog/Py/AllMetrics_Jan31/deviceSoEu1.csv')
data.head()
# Out:
#        ds Region      Device    y
# 0  1/1/17     CE     desktop  570
# 1  1/1/17     CE  mobile App   25
# 2  1/1/17     CE  mobile web   72
# 3  1/1/17     CE      tablet  191
# 4  1/1/17     CE     Unknown  125

# %%
from time_series_multireg.multireg_forecast import multireg_forecast
#xUK = multireg_forecast(data, 365, date_col="ds", measure_col="y", region_col="Region", 
#                         forecasts = {"holtwinters", "arima_stlm", "sarima_stlm", "prophet"})
#xFR = multireg_forecast(data, 365, date_col="ds", measure_col="y", region_col="Region", 
#                         forecasts = {"holtwinters", "arima_stlm", "sarima_stlm", "prophet"})
xCE = multireg_forecast(data, 365, date_col="ds", measure_col="y", region_col="Region", 
                         forecasts = {"holtwinters", "arima_stlm", "sarima_stlm", "prophet"})
#xSoEu = multireg_forecast(data, 365, date_col="ds", measure_col="y", region_col="Region", 
#                         forecasts = {"holtwinters", "arima_stlm", "sarima_stlm", "prophet"})
# Out:
# 2019-02-12 14:38:05.346 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:224 - Determining best forecast for Unknown, CE.
# 2019-02-12 14:38:05.529 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:238 - In sample actuals: 761.
# 2019-02-12 14:38:05.530 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:239 - Out sample actuals: 0.
# 2019-02-12 14:38:05.530 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:247 - Performing holtwinters on Unknown, CE.
# 2019-02-12 14:38:09.835 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:272 - holtwinters produced mape 0.281.
# 2019-02-12 14:38:09.836 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:274 - Best mape: inf.
# 2019-02-12 14:38:09.837 | DEBUG    | time_series_multireg.multireg_forecast:multireg_forecast:282 - New best mape: 0.281.
# ...

# %%
#pred = xUK
#pred = xFR
pred = xCE
#pred = xSoEu

bestOut = pd.DataFrame(columns=pred[0])
for key in pred[0]:
    bestOut[key[0]] = list(pred[0][key][0:2]) + list(pred[0][key][2])

#bestOut.to_csv('/Users/akuppam/Documents/Hprog/Py/AllMetrics_Jan31/xUK.csv')
#bestOut.to_csv('/Users/akuppam/Documents/Hprog/Py/AllMetrics_Jan31/xFR.csv')
bestOut.to_csv('/Users/akuppam/Documents/Hprog/Py/AllMetrics_Jan31/xCE.csv')
#bestOut.to_csv('/Users/akuppam/Documents/Hprog/Py/AllMetrics_Jan31/xSoEu.csv')

# %%
pred[0]
# Out:
# {('Unknown', 'CE'): ('sarima_stlm',
#   0.21280587098297285,
#   2017-01-01    124.971999
#   2017-01-02    204.985263
#   2017-01-03    166.989233
#   2017-01-04    245.916960
#   2017-01-05    176.979276
#   2017-01-06    195.088932
#   2017-01-07    155.097654
#   2017-01-08    300.922442
#   2017-01-09    198.940795
#   2017-01-10    193.955540
#   2017-01-11    196.928304
#   2017-01-12    162.969652
#   2017-01-13    147.125307
#   2017-01-14    219.069423
#   2017-01-15    349.879668
#   2017-01-16    251.915307
#   2017-01-17    177.922933
#   2017-01-18    187.896678
#   2017-01-19    228.872883
#   2017-01-20    191.049440
#   2017-01-21    215.030162
#   2017-01-22    327.876328
#   2017-01-23    236.893505
#   2017-01-24    216.892997
#   2017-01-25    180.874137
#   2017-01-26    199.893367
#   2017-01-27    151.044624
#   2017-01-28    188.034355
#   2017-01-29    375.836983
#   2017-01-30    239.887659
#                    ...
#   2020-01-02    623.000000
# ...

# %%
pred[1]
# Out:
# {('Unknown', 'CE', 'holtwinters'): (0.28080399421991903,
#   2017-01-01           NaN
#   2017-01-02           NaN
#   2017-01-03           NaN
#   2017-01-04           NaN
#   2017-01-05           NaN
#   2017-01-06           NaN
#   2017-01-07           NaN
#   2017-01-08           NaN
#   2017-01-09           NaN
#   2017-01-10           NaN
#   2017-01-11           NaN
#   2017-01-12           NaN
#   2017-01-13           NaN
#   2017-01-14           NaN
#   2017-01-15           NaN
#   2017-01-16           NaN
#   2017-01-17           NaN
#   2017-01-18           NaN
#   2017-01-19           NaN
#   2017-01-20           NaN
#   2017-01-21           NaN
#   2017-01-22           NaN
#   2017-01-23           NaN
#   2017-01-24           NaN
#   2017-01-25           NaN
#   2017-01-26           NaN
#   2017-01-27           NaN
#   2017-01-28           NaN
#   2017-01-29           NaN
#   2017-01-30           NaN
#                    ...
#   2020-01-02    660.261883
# ...

# %%
pred[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-98-98238358f737> in <module>()
# ----> 1 pred[2]
#
# IndexError: tuple index out of range

# %%
pd.DataFrame(columns=pred[0])
# Out:
# Empty DataFrame
# Columns: [(Unknown, CE), (desktop, CE), (mobile App, CE), (mobile web, CE), (tablet, CE)]
# Index: []

# %%
d = {'AA': [('No Av', 'Ave', 3.35, 'Max', 0.9, 'Min', -6.8),
            ('analist disp:', -5.0), u' AA: Jan 11, 2016\t\t\t']}


def flat(xs):
    for x in xs:
        if isinstance(x, (list, tuple)):
            for y in flat(x):
                yield y
        else:
            yield x

# If there's only one item in the dictionary
next([key] + list(flat(value)) for key, value in d.items())
# => ['AA', 'No Av', 'Ave', 3.35, 'Max', 0.9, 'Min', -6.8, 'analist disp:',
#     -5.0, u' AA: Jan 11, 2016\t\t\t']
# Out:
# ['AA',
#  'No Av',
#  'Ave',
#  3.35,
#  'Max',
#  0.9,
#  'Min',
#  -6.8,
#  'analist disp:',
#  -5.0,
#  ' AA: Jan 11, 2016\t\t\t']

# %%
#If there are multiple items, use following instead:

import itertools
list(itertools.chain.from_iterable(
    [key] + list(flat(value)) for key, value in d.items()
))
# => ['AA', 'No Av', 'Ave', 3.35, 'Max', 0.9, 'Min', -6.8, 'analist disp:',
#     -5.0, u' AA: Jan 11, 2016\t\t\t']
# Out:
# ['AA',
#  'No Av',
#  'Ave',
#  3.35,
#  'Max',
#  0.9,
#  'Min',
#  -6.8,
#  'analist disp:',
#  -5.0,
#  ' AA: Jan 11, 2016\t\t\t']

# %%
xAllReg = {('Unknown', 'SoEu'): ('sarima_stlm', 0.2858003238752771, 945)}

# %%
xAllReg = {('Unknown', 'CE'): ('sarima_stlm',
  0.21280587098297285,
  '2017/1/1'    '124.971999'
),
 ('desktop', 'CE'): ('sarima_stlm',
  0.09286572932634628,
)}

# %%
d = {'AA': [('No Av', 'Ave', 3.35, 'Max', 0.9, 'Min', -6.8),
            ('analist disp:', -5.0), u' AA: Jan 11, 2016\t\t\t']}

# %%
d = {'AA': [('No Av', 'Ave', 3.35, 'Max', 0.9, 'Min', -6.8),
            ('analist disp:', -5.0), u' AA: Jan 11, 2016\t\t\t']}

# %%
xAllReg.items()
# Out:
# dict_items([(('Unknown', 'CE'), ('sarima_stlm', 0.21280587098297285, '2017/1/1124.971999')), (('desktop', 'CE'), ('sarima_stlm', 0.09286572932634628))])

# %%
import itertools
list(itertools.chain.from_iterable(
    [key] + list(flat(value)) for key, value in xAllReg.items()
))
# Out:
# [('Unknown', 'CE'),
#  'sarima_stlm',
#  0.21280587098297285,
#  '2017/1/1124.971999',
#  ('desktop', 'CE'),
#  'sarima_stlm',
#  0.09286572932634628]

# %%
pred[0]
# Out:
# {('Unknown', 'CE'): ('sarima_stlm',
#   0.21280587098297285,
#   2017-01-01    124.971999
#   2017-01-02    204.985263
#   2017-01-03    166.989233
#   2017-01-04    245.916960
#   2017-01-05    176.979276
#   2017-01-06    195.088932
#   2017-01-07    155.097654
#   2017-01-08    300.922442
#   2017-01-09    198.940795
#   2017-01-10    193.955540
#   2017-01-11    196.928304
#   2017-01-12    162.969652
#   2017-01-13    147.125307
#   2017-01-14    219.069423
#   2017-01-15    349.879668
#   2017-01-16    251.915307
#   2017-01-17    177.922933
#   2017-01-18    187.896678
#   2017-01-19    228.872883
#   2017-01-20    191.049440
#   2017-01-21    215.030162
#   2017-01-22    327.876328
#   2017-01-23    236.893505
#   2017-01-24    216.892997
#   2017-01-25    180.874137
#   2017-01-26    199.893367
#   2017-01-27    151.044624
#   2017-01-28    188.034355
#   2017-01-29    375.836983
#   2017-01-30    239.887659
#                    ...
#   2020-01-02    623.000000
# ...

# %%
import itertools
list(itertools.chain.from_iterable(
    [key] + list(flat(value)) for key, value in pred[0].items()
))
# Out:
# [('Unknown', 'CE'),
#  'sarima_stlm',
#  0.21280587098297285,
#  2017-01-01    124.971999
#  2017-01-02    204.985263
#  2017-01-03    166.989233
#  2017-01-04    245.916960
#  2017-01-05    176.979276
#  2017-01-06    195.088932
#  2017-01-07    155.097654
#  2017-01-08    300.922442
#  2017-01-09    198.940795
#  2017-01-10    193.955540
#  2017-01-11    196.928304
#  2017-01-12    162.969652
#  2017-01-13    147.125307
#  2017-01-14    219.069423
#  2017-01-15    349.879668
#  2017-01-16    251.915307
#  2017-01-17    177.922933
#  2017-01-18    187.896678
#  2017-01-19    228.872883
#  2017-01-20    191.049440
#  2017-01-21    215.030162
#  2017-01-22    327.876328
#  2017-01-23    236.893505
#  2017-01-24    216.892997
#  2017-01-25    180.874137
#  2017-01-26    199.893367
#  2017-01-27    151.044624
#  2017-01-28    188.034355
#  2017-01-29    375.836983
#  2017-01-30    239.887659
#                   ...
#  2020-01-02    623.000000
#  2020-01-03    529.000000
# ...

# %%
import itertools
pred1 = list(itertools.chain.from_iterable(
    [key] + list(flat(value)) for key, value in pred[0].items()
))

# %%
import csv
with open('pred1_test3.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(pred1)

# %%
import itertools
pred2 = list(itertools.chain.from_iterable(
    [key] + list(flat(value)) for key, value in pred[0][key][2].items()
))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-f66b452e0ad8> in <module>()
#       1 import itertools
#       2 pred2 = list(itertools.chain.from_iterable(
# ----> 3     [key] + list(flat(value)) for key, value in pred[0][key][2].items()
#       4 ))
#
# <ipython-input-150-f66b452e0ad8> in <genexpr>(.0)
#       1 import itertools
#       2 pred2 = list(itertools.chain.from_iterable(
# ----> 3     [key] + list(flat(value)) for key, value in pred[0][key][2].items()
#       4 ))
#
# <ipython-input-100-8035e5c67536> in flat(xs)
#       4
#       5 def flat(xs):
# ----> 6     for x in xs:
#       7         if isinstance(x, (list, tuple)):
#       8             for y in flat(x):
#
# TypeError: 'float' object is not iterable

# %%
allOut = pd.DataFrame(columns=pred[1])

# %%
for key in pred[1]:
    allOut[key[0]] = list(pred[1]([key][0][key][0:2])) + list(pred[1]([key][0][key][2]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-6559b50910e5> in <module>()
#       1 for key in pred[1]:
# ----> 2     allOut[key[0]] = list(pred[1]([key][0][key][0:2])) + list(pred[1]([key][0][key][2]))
#
# TypeError: tuple indices must be integers or slices, not tuple

# %%
b1 = pd.DataFrame(columns=pred[0])
for key in pred[0]:
    b1[key[0]] = list(pred[0][key][0:2]) + list(pred[0][key][2])

# %%
b1.head()
# Out:
#        Unknown      desktop   mobile App   mobile web       tablet
#             CE           CE           CE           CE           CE
# 0  sarima_stlm  sarima_stlm  holtwinters  sarima_stlm  sarima_stlm
# 1     0.212806    0.0928657    0.0090707    0.0880288     0.134368
# 2      124.972      569.871          NaN      72.0033      190.999
# 3      204.985      774.014          NaN      110.025      205.985
# 4      166.989      753.044          NaN      103.006      171.017

# %%
b1 = pd.DataFrame(columns=pred[0])
for key in pred[0]:
    b1[key[0]] = list(pred[0][key][0:2]) + list(pred[0][key][2])

# %%
b1.head()
# Out:
#        Unknown      desktop   mobile App   mobile web       tablet
#             CE           CE           CE           CE           CE
# 0  sarima_stlm  sarima_stlm  holtwinters  sarima_stlm  sarima_stlm
# 1     0.212806    0.0928657    0.0090707    0.0880288     0.134368
# 2      124.972      569.871          NaN      72.0033      190.999
# 3      204.985      774.014          NaN      110.025      205.985
# 4      166.989      753.044          NaN      103.006      171.017

# %%
b2 = pd.DataFrame(columns=pred[0])
for key in pred[0]:
    b2[key[1]] = list(pred[0][key][0:2]) + list(pred[0][key][2])

# %%
b2.head()
# Out:
#   Unknown desktop mobile App mobile web tablet           CE
#        CE      CE         CE         CE     CE
# 0     NaN     NaN        NaN        NaN    NaN  sarima_stlm
# 1     NaN     NaN        NaN        NaN    NaN     0.134368
# 2     NaN     NaN        NaN        NaN    NaN      190.999
# 3     NaN     NaN        NaN        NaN    NaN      205.985
# 4     NaN     NaN        NaN        NaN    NaN      171.017

# %%
import pandas as pd
xAll_regions_2 = pd.read_csv('/Users/akuppam/Documents/Hprog/Py/AllMetrics_Jan31/xAll_regions_2.txt')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-177-aec3b4d3d0bc> in <module>()
#       1 import pandas as pd
# ----> 2 xAll_regions_2 = pd.read_csv('/Users/akuppam/Documents/Hprog/Py/AllMetrics_Jan31/xAll_regions_2.txt')
#
# ...
